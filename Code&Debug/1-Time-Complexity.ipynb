# %% [markdown]
# # Time Complexity
#
# Rate of increase in time with respect to input size
#
# TC -> Big-oh Notation -> O( Your time taken )
# 1. Always calculate TC in terms of worst case
# 2. Avoid the constant values
# 3. Avoid lower bound

# %% [markdown]
# # Space Complexity
#
# Memory Space -> Big Oh Notation
#
# Auxiliary Space + Input Space
# 1. Auxiliary Space -> The extra space used to solve the problem
# 2. Input space -> The space used to store the input

# %% [markdown]
# # Time Limit Exceeded Error [TLE]
#
# Code --------------------> Server
#
# 1. Time Limit Constraints -> 1 sec -> 10^8 Operation
#
# List = [1,2,3,4,5,6,7,8]
#
# TC-> N^2
# Constraints = 1<N<10^5
#
# Worst case -> (10^5)^2 = 10^10

# %% [markdown]
# # Time Complexity of Common Python Operations & Methods

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Extraction of Digits Using Loops

# %%
def dig_extract(n):
    num = n
    while(0<len(num)):
        last_digit = num%10
        print(last_digit)
        num = num // 10
        
dig_extract(3452345)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-43b472dc52f1> in <module>
#       6         num = num // 10
#       7
# ----> 8 dig_extract(3452345)
#
# <ipython-input-1-43b472dc52f1> in dig_extract(n)
#       1 def dig_extract(n):
#       2     num = n
# ----> 3     while(0<len(num)):
#       4         last_digit = num%10
#       5         print(last_digit)
#
# TypeError: object of type 'int' has no len()
